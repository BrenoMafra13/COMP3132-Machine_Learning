# %% [markdown]
# <a href="https://colab.research.google.com/github/BrenoMafra13/COMP3132-Machine_Learning/blob/main/assignments/assign2_Breno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 02
# The following assignment is a step-by-step process to implement a multiclass classification using Iris dataset.
#
# **Note:**
#
# - Please note that every question has 0.5 and it provides five out of total ten marks for the assignment. 5/10%
#
# The video presentation 5/10%.
#
# Without YouTube presentation you receive no mark for the submission.

# %%
#00 The iris.csv file (Iris dataset) is located in the Assignment folder below the current ipynb file.

# %% [markdown]
#  **Important Note:** We are NOT allowed to import the dataset from Keras. We need to upload the provided iris.csv file to colab from our Google Drive.

# %%
#00 1st, upload the iris.csv into your Google Drive (your Colab folder).

# %%
#01-a Find the path of iris.csv file, and save it in a variable called fileName.

# %%
fileName = './Assignment_02_iris.csv'

# %%
#01-b Read the content of the iris.csv file and save it in a variable, named iris.

# %%
import pandas as pd
iris = pd.read_csv(fileName)

# %%
#01-c Show the first 5 rows of the dataframe.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# As you see, the last column contains strings. We want to convert these strings to integers,  and we can work with them easily in our Neural Network model.
#
# setosa -> 0
#
# versicolor -> 1
#
# virginica -> 2

# %%
#2-a Convert the last column strings to integers, as
# setosa -> 0
# versicolor -> 1
# virginica -> 2

# %%
mapping = {'setosa': 0, 'versicolor': 1, 'virginica': 2}
iris['species'] = iris['species'].map(mapping)

# %%
#2-b Now, check the first 5 elements of the iris dataset once again:

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#03-a Select the first four columns of the dataframe as the Data and call the data x.

# %%
x = iris.iloc[:, :4]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#03-b Select the last column as the label and call it y.

# %%
y = iris.iloc[:, -1]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
#04 Now, it is the time to split the data (x) and the label (y) into training and testin segments,
#   and call them parts x_train,x_test,y_train,y_test.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (120, 4) (30, 4)
# (120,) (30,)

# %%
#04-a Split the data, and label ito training and testing segments, while the size of test data is 20%,
#     and use randome_state = 123 to make all the answers similar in the whole class.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=123)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (120, 4) (30, 4)
# (120,) (30,)

# %%
#04-b Check the first five rows of  x_train,x_test,y_train,y_test.

# %%
x_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 130           7.4          2.8           6.1          1.9
# 119           6.0          2.2           5.0          1.5
# 29            4.7          3.2           1.6          0.2
# 0             5.1          3.5           1.4          0.2
# 62            6.0          2.2           4.0          1.0

# %%
x_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 72            6.3          2.5           4.9          1.5
# 112           6.8          3.0           5.5          2.1
# 132           6.4          2.8           5.6          2.2
# 88            5.6          3.0           4.1          1.3
# 37            4.9          3.1           1.5          0.1

# %%
y_train.head()
# Out:
# 130    2
# 119    2
# 29     0
# 0      0
# 62     1
# Name: species, dtype: int64

# %%
y_test.head()
# Out:
# 72     1
# 112    2
# 132    2
# 88     1
# 37     0
# Name: species, dtype: int64

# %%
#04-c Check the length of the x_train and x_test. If the numbers are 120 & 30, AWESOME!
#     You are good to continue!

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
#05-a Convert y_train and y_test from categorical to one-hot encoded values, and call them
#     one_hot_train_labels, and one_hot_test_labels, respectively.

# %%
from tensorflow.keras.utils import to_categorical

one_hot_train_labels = to_categorical(y_train)
one_hot_test_labels = to_categorical(y_test)

# %%
#06-a Define a sequential model that contains 3 dense layers.
#     In the first and second layers, use 100 hidden units (neurons) and a 'relu' activation function.
#     For the last layer, we need to use 3 as the number of output,
#     and the reason is we have three classes (setosa -> 0, versicolor -> 1, virginica -> 2)
#     Also, please pick an appropriate loss function for the last layer.
#     (You may already have guessed what could be the best loss function when we have converted the categorical values to encoded values.)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
    Dense(100, activation='relu', input_shape=(4,)),
    Dense(100, activation='relu'),
    Dense(3, activation='softmax')
])

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#06-b Now, compile your model using the 'rmsprop' optimizer, an appropriate loss function, and 'accuracy' for your metrics.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
#07-a Train your model using epoch=20, batch=10.

# %%
model.fit(x_train, one_hot_train_labels, epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9460 - loss: 0.1318
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9613 - loss: 0.1075
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9943 - loss: 0.0987
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9612 - loss: 0.1290
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9551 - loss: 0.1195
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9587 - loss: 0.1220
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9720 - loss: 0.0862
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9714 - loss: 0.0954
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0671
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9795 - loss: 0.0713
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9568 - loss: 0.0764
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9811 - loss: 0.0867
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9740 - loss: 0.0916
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.0649
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9890 - loss: 0.0657
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9585 - loss: 0.1086
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9218 - loss: 0.1070
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9542 - loss: 0.0831
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9680 - loss: 0.1205
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9373 - loss: 0.1432

# %%
#08-a Calculate the result, evaluating x_test and one_hot_test_label, and report on the accuracy of your model.

# %%
loss, accuracy = model.evaluate(x_test, one_hot_test_labels)
print('Accuracy: ', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9667 - loss: 0.1146
# Accuracy:  0.9666666388511658

# %%
#09-a Now, we repeat all we have done in #06-a with the following parameters:
#     In the first and second hidden layers, use 10 hidden units (neurons) and a 'relu' activation function.
#     For the output layer, we need to use 3.

# %%
model_modified = Sequential([
    Dense(10, activation='relu', input_shape=(4,)),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#09-b Use the same settings as for #06-b (compile using the same optimizer, loss function) and output the accuracy

# %%
model_modified.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
#09-c Please fit your model using epoch=4, batch=10.

# %%
model_modified.fit(x_train, one_hot_train_labels, epochs=4, batch_size=10)
# Out:
# Epoch 1/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7005 - loss: 0.8067
# Epoch 2/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9685 - loss: 0.7114
# Epoch 3/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9834 - loss: 0.6619
# Epoch 4/4
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9317 - loss: 0.6488

# %%
#09-d Calculate the result, evaluating x_test and one_hot_test_label, and report on the accuracy of your model.

# %%
loss, accuracy = model_modified.evaluate(x_test, one_hot_test_labels)
print('Accuracy: ', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9333 - loss: 0.5553
# Accuracy:  0.9333333373069763

# %%
#10-a In your video submission, explain each line of your code, and the arguments you've used
# Ensure to answer the following questions at a minimum:
# 10-a-i) How the number of layers or hidden units could impact the accuracy of our model.
# 10-a-ii) Do we always suffer from overfitting?
# 10-a-iii) How can we detect overfitting?
# 10-a-iv) How can we reduce overfitting?

# %% [markdown]
# **(Answers for #10-a will be only answered in video)**

# %%
#10-b
# Use different settings than the ones we chose in #09
# Change each of the following once:
#   i)   optimizer
#   ii)  number of layers
#   iii) hidden units
#   iv)  number of epochs
#   v)   batch_size
# Change one parameter at a time, and rerun the cell(s), then explain the output

# %% [markdown]
# **(Each one of the changes are made in video.)**

# %%
model_10b = Sequential([
    Dense(10, activation='relu'),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')
])

# %%
model_10b.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model_10b.fit(x_train, one_hot_train_labels, epochs=10, batch_size=5)
# Out:
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2860 - loss: 1.4473
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3420 - loss: 1.1556
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5677 - loss: 1.0883
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5708 - loss: 1.0082
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5913 - loss: 0.9583
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6445 - loss: 0.9294
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6820 - loss: 0.8699
# Epoch 8/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6426 - loss: 0.8350
# Epoch 9/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6271 - loss: 0.8074
# Epoch 10/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6455 - loss: 0.7514

# %%
loss, accuracy = model_10b.evaluate(x_test, one_hot_test_labels)
print('Accuracy: ', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8000 - loss: 0.6622
# Accuracy:  0.800000011920929

# %% [markdown]
# ---
# # Deliverables:
# 1. Submit the current ipynb file on D2L
# 2. Please record and upload to YouTube 3-6 minute recorded video clip (aim for 5 minutes) describing the answers to the questions above, espcially #10.
#
# Notes:
# - In your submission, YOU MUST SUBMIT A LINK TO YOUR YOUTUBE VIDEO as a TEXT SUBMISSION SECTION on your D2L submission.
# - Omitting this D2L comment will result in a 0% for your total mark.
